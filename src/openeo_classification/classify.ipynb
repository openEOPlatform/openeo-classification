# %%
import pandas as pd

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix,plot_confusion_matrix
from catboost import CatBoostClassifier
import matplotlib.pyplot as plt
from explore import all_crop_codes
import math

# %%
df = pd.read_csv("resources/training_data/final_features.csv",index_col=0)

# %%
band_names = ["B06", "B12"] + ["NDVI", "NDMI", "NDGI", "ANIR", "NDRE1", "NDRE2", "NDRE5"] + ["ratio", "VV", "VH"]
tstep_labels = ["t" + str(4 * index) for index in range(0, 6)]
all_bands = [band + "_" + stat for band in band_names for stat in ["p10", "p50", "p90", "sd"] + tstep_labels]

# %%
df["ids"].unique()
# Out:
# array([910091109120,         1200,         1510,         1910,
#                4351,         5100,         1110,         8100],
#       dtype=int64)

# %%
df["y"] = df["ids"].apply(lambda num: all_crop_codes[num // 10 ** (int(math.log(num, 10)) - 4 + 1)])
X = df[all_bands]
y = df["y"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
param_grid = {'learning_rate': [0.07],#[0.03, 0.1],
        'depth': [4,10,20],#[4, 6, 10] ### 10 beter dan 4 (~0.02 accuracy verschil), 20 kan niet
        'l2_leaf_reg': [4,10,20],#[1, 3, 5,], ### 4 beter dan 10 (~0.02 accuracy verschil), 20 nog slechter 
        'iterations': [150]}#, 100, 150]}
cb = CatBoostClassifier()
grid_search = GridSearchCV(estimator = cb, param_grid = param_grid, cv = 3, n_jobs = -1)

# %%
grid_search.fit(X_train, y_train)
grid_search.best_params_
# Out:
# c:\users\driesseb\.conda\envs\openeo\lib\site-packages\sklearn\model_selection\_search.py:922: UserWarning: One or more of the test scores are non-finite: [0.72650024 0.71948738 0.71264086 0.74553522 0.728504   0.71548003
#         nan        nan        nan]
#   warnings.warn(
# 0:	learn: 1.9724374	total: 2.75s	remaining: 6m 49s
# 1:	learn: 1.8700904	total: 5.42s	remaining: 6m 41s
# 2:	learn: 1.7742679	total: 8.04s	remaining: 6m 33s
# 3:	learn: 1.6950379	total: 10.7s	remaining: 6m 28s
# 4:	learn: 1.6300055	total: 13.2s	remaining: 6m 23s
# 5:	learn: 1.5682136	total: 15.9s	remaining: 6m 21s
# 6:	learn: 1.5205639	total: 18.5s	remaining: 6m 17s
# 7:	learn: 1.4671221	total: 21.1s	remaining: 6m 14s
# 8:	learn: 1.4239101	total: 23.7s	remaining: 6m 11s
# 9:	learn: 1.3869271	total: 26.3s	remaining: 6m 8s
# 10:	learn: 1.3457934	total: 28.9s	remaining: 6m 5s
# 11:	learn: 1.3160661	total: 31.5s	remaining: 6m 2s
# 12:	learn: 1.2869072	total: 34.2s	remaining: 6m
# 13:	learn: 1.2583854	total: 36.8s	remaining: 5m 57s
# 14:	learn: 1.2271466	total: 39.3s	remaining: 5m 53s
# 15:	learn: 1.2010176	total: 41.9s	remaining: 5m 51s
# 16:	learn: 1.1752045	total: 44.6s	remaining: 5m 48s
# 17:	learn: 1.1513124	total: 47.1s	remaining: 5m 45s
# 18:	learn: 1.1269891	total: 49.7s	remaining: 5m 42s
# 19:	learn: 1.1058199	total: 52.3s	remaining: 5m 40s
# 20:	learn: 1.0864541	total: 54.9s	remaining: 5m 37s
# 21:	learn: 1.0675867	total: 57.5s	remaining: 5m 34s
# 22:	learn: 1.0506955	total: 1m	remaining: 5m 32s
# 23:	learn: 1.0336205	total: 1m 2s	remaining: 5m 29s
# 24:	learn: 1.0162034	total: 1m 5s	remaining: 5m 26s
# 25:	learn: 1.0025783	total: 1m 7s	remaining: 5m 24s
# 26:	learn: 0.9886154	total: 1m 10s	remaining: 5m 21s
# 27:	learn: 0.9749751	total: 1m 13s	remaining: 5m 18s
# 28:	learn: 0.9597919	total: 1m 15s	remaining: 5m 16s
# 29:	learn: 0.9476931	total: 1m 18s	remaining: 5m 13s
# 30:	learn: 0.9346459	total: 1m 20s	remaining: 5m 10s
# 31:	learn: 0.9225275	total: 1m 23s	remaining: 5m 7s
# 32:	learn: 0.9101941	total: 1m 26s	remaining: 5m 5s
# 33:	learn: 0.9003120	total: 1m 28s	remaining: 5m 2s
# 34:	learn: 0.8903962	total: 1m 31s	remaining: 4m 59s
# 35:	learn: 0.8806802	total: 1m 33s	remaining: 4m 57s
# 36:	learn: 0.8715289	total: 1m 36s	remaining: 4m 54s
# 37:	learn: 0.8627785	total: 1m 39s	remaining: 4m 52s
# 38:	learn: 0.8540306	total: 1m 41s	remaining: 4m 50s
# 39:	learn: 0.8458449	total: 1m 45s	remaining: 4m 48s
# 40:	learn: 0.8379007	total: 1m 47s	remaining: 4m 46s
# 41:	learn: 0.8301158	total: 1m 50s	remaining: 4m 43s
# 42:	learn: 0.8223038	total: 1m 52s	remaining: 4m 40s
# 43:	learn: 0.8140031	total: 1m 55s	remaining: 4m 38s
# 44:	learn: 0.8061107	total: 1m 58s	remaining: 4m 35s
# 45:	learn: 0.7996879	total: 2m	remaining: 4m 32s
# 46:	learn: 0.7925359	total: 2m 3s	remaining: 4m 30s
# 47:	learn: 0.7857476	total: 2m 5s	remaining: 4m 27s
# 48:	learn: 0.7782596	total: 2m 8s	remaining: 4m 25s
# 49:	learn: 0.7718865	total: 2m 11s	remaining: 4m 22s
# 50:	learn: 0.7656102	total: 2m 13s	remaining: 4m 20s
# 51:	learn: 0.7594550	total: 2m 16s	remaining: 4m 17s
# 52:	learn: 0.7536239	total: 2m 19s	remaining: 4m 14s
# 53:	learn: 0.7478239	total: 2m 21s	remaining: 4m 12s
# 54:	learn: 0.7420715	total: 2m 24s	remaining: 4m 9s
# 55:	learn: 0.7364996	total: 2m 27s	remaining: 4m 6s
# 56:	learn: 0.7299304	total: 2m 29s	remaining: 4m 4s
# 57:	learn: 0.7245971	total: 2m 32s	remaining: 4m 1s
# 58:	learn: 0.7190640	total: 2m 34s	remaining: 3m 58s
# 59:	learn: 0.7136157	total: 2m 37s	remaining: 3m 56s
# 60:	learn: 0.7079158	total: 2m 40s	remaining: 3m 53s
# 61:	learn: 0.7027315	total: 2m 42s	remaining: 3m 51s
# 62:	learn: 0.6975271	total: 2m 45s	remaining: 3m 48s
# 63:	learn: 0.6923750	total: 2m 47s	remaining: 3m 45s
# 64:	learn: 0.6880841	total: 2m 50s	remaining: 3m 43s
# 65:	learn: 0.6835893	total: 2m 53s	remaining: 3m 40s
# 66:	learn: 0.6790376	total: 2m 55s	remaining: 3m 37s
# 67:	learn: 0.6745282	total: 2m 58s	remaining: 3m 35s
# 68:	learn: 0.6699842	total: 3m 1s	remaining: 3m 32s
# 69:	learn: 0.6658415	total: 3m 3s	remaining: 3m 29s
# 70:	learn: 0.6614231	total: 3m 6s	remaining: 3m 27s
# 117:	learn: 0.5103878	total: 5m 9s	remaining: 1m 24s
# 118:	learn: 0.5078575	total: 5m 12s	remaining: 1m 21s
# 119:	learn: 0.5054207	total: 5m 15s	remaining: 1m 18s
# 120:	learn: 0.5031799	total: 5m 17s	remaining: 1m 16s
# 121:	learn: 0.5007404	total: 5m 20s	remaining: 1m 13s
# 122:	learn: 0.4984422	total: 5m 23s	remaining: 1m 11s
# 123:	learn: 0.4964129	total: 5m 26s	remaining: 1m 8s
# 124:	learn: 0.4940034	total: 5m 29s	remaining: 1m 5s
# 125:	learn: 0.4919307	total: 5m 31s	remaining: 1m 3s
# 126:	learn: 0.4897616	total: 5m 34s	remaining: 1m
# 127:	learn: 0.4876240	total: 5m 37s	remaining: 58s
# 128:	learn: 0.4855715	total: 5m 40s	remaining: 55.4s
# 129:	learn: 0.4838790	total: 5m 43s	remaining: 52.8s
# 130:	learn: 0.4820983	total: 5m 45s	remaining: 50.2s
# 131:	learn: 0.4800433	total: 5m 48s	remaining: 47.5s
# 132:	learn: 0.4778447	total: 5m 51s	remaining: 44.9s
# 133:	learn: 0.4754415	total: 5m 54s	remaining: 42.3s
# 134:	learn: 0.4732963	total: 5m 56s	remaining: 39.6s
# 135:	learn: 0.4710348	total: 5m 59s	remaining: 37s
# 136:	learn: 0.4691442	total: 6m 2s	remaining: 34.4s
# 137:	learn: 0.4671042	total: 6m 4s	remaining: 31.7s
# 138:	learn: 0.4652402	total: 6m 7s	remaining: 29.1s
# 139:	learn: 0.4637870	total: 6m 10s	remaining: 26.4s
# 140:	learn: 0.4620235	total: 6m 13s	remaining: 23.8s
# 141:	learn: 0.4604067	total: 6m 15s	remaining: 21.2s
# 142:	learn: 0.4588851	total: 6m 18s	remaining: 18.5s
# 143:	learn: 0.4568416	total: 6m 21s	remaining: 15.9s
# 144:	learn: 0.4551256	total: 6m 23s	remaining: 13.2s
# 145:	learn: 0.4533305	total: 6m 26s	remaining: 10.6s
# 146:	learn: 0.4515632	total: 6m 29s	remaining: 7.94s
# 147:	learn: 0.4500152	total: 6m 32s	remaining: 5.3s
# 148:	learn: 0.4484335	total: 6m 34s	remaining: 2.65s
# 149:	learn: 0.4472153	total: 6m 37s	remaining: 0us
# {'depth': 10, 'iterations': 150, 'l2_leaf_reg': 4, 'learning_rate': 0.07}

# %%
gs_results = pd.DataFrame(grid_search.cv_results_).sort_values(by=["mean_test_score"],axis=0,ascending=False)
print(gs_results.head())
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_depth  \
# 3    2827.030459      9.079513         1.373186        0.782502          10
# 4    2834.905129      2.291468         0.659074        0.406151          10
# 0      43.716978      1.786057         0.360187        0.132006           4
# 1      38.894648      2.826189         0.134575        0.067611           4
# 5    1982.432080   1096.855543         0.533187        0.651618          10
#
#   param_iterations param_l2_leaf_reg param_learning_rate  \
# 3              150                 4                0.07
# 4              150                10                0.07
# 0              150                 4                0.07
# 1              150                10                0.07
# 5              150                20                0.07
#
#                                               params  split0_test_score  \
# 3  {'depth': 10, 'iterations': 150, 'l2_leaf_reg'...           0.735103
# 4  {'depth': 10, 'iterations': 150, 'l2_leaf_reg'...           0.718077
# 0  {'depth': 4, 'iterations': 150, 'l2_leaf_reg':...           0.716575
# 1  {'depth': 4, 'iterations': 150, 'l2_leaf_reg':...           0.709564
# 5  {'depth': 10, 'iterations': 150, 'l2_leaf_reg'...           0.705558
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 3           0.748998           0.752505         0.745535        0.007515
# 4           0.730962           0.736473         0.728504        0.007709
# 0           0.733467           0.729459         0.726500        0.007207
# 1           0.721944           0.726954         0.719487        0.007309
# 5           0.719439           0.721443         0.715480        0.007063
#
#    rank_test_score
# 3                1
# 4                2
# 0                3
# 1                4
# 5                5

# %%
gs_results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_depth  \
# 3    2827.030459      9.079513         1.373186        0.782502          10
# 4    2834.905129      2.291468         0.659074        0.406151          10
# 0      43.716978      1.786057         0.360187        0.132006           4
# 1      38.894648      2.826189         0.134575        0.067611           4
# 5    1982.432080   1096.855543         0.533187        0.651618          10
# 2      97.029415     77.968264         0.536097        0.394589           4
# 6       0.290054      0.104142         0.000000        0.000000          20
# 7       0.398036      0.219770         0.000000        0.000000          20
# 8       0.250971      0.098238         0.000000        0.000000          20
#
#   param_iterations param_l2_leaf_reg param_learning_rate  \
# 3              150                 4                0.07
# 4              150                10                0.07
# 0              150                 4                0.07
# 1              150                10                0.07
# 5              150                20                0.07
# 2              150                20                0.07
# 6              150                 4                0.07
# 7              150                10                0.07
# 8              150                20                0.07
#
#                                               params  split0_test_score  \
# 3  {'depth': 10, 'iterations': 150, 'l2_leaf_reg'...           0.735103
# 4  {'depth': 10, 'iterations': 150, 'l2_leaf_reg'...           0.718077
# 0  {'depth': 4, 'iterations': 150, 'l2_leaf_reg':...           0.716575
# 1  {'depth': 4, 'iterations': 150, 'l2_leaf_reg':...           0.709564
# 5  {'depth': 10, 'iterations': 150, 'l2_leaf_reg'...           0.705558
# 2  {'depth': 4, 'iterations': 150, 'l2_leaf_reg':...           0.706560
# 6  {'depth': 20, 'iterations': 150, 'l2_leaf_reg'...                NaN
# 7  {'depth': 20, 'iterations': 150, 'l2_leaf_reg'...                NaN
# 8  {'depth': 20, 'iterations': 150, 'l2_leaf_reg'...                NaN
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 3           0.748998           0.752505         0.745535        0.007515
# 4           0.730962           0.736473         0.728504        0.007709
# 0           0.733467           0.729459         0.726500        0.007207
# 1           0.721944           0.726954         0.719487        0.007309
# 5           0.719439           0.721443         0.715480        0.007063
# 2           0.716433           0.714930         0.712641        0.004343
# 6                NaN                NaN              NaN             NaN
# 7                NaN                NaN              NaN             NaN
# 8                NaN                NaN              NaN             NaN
#
#    rank_test_score
# 3                1
# 4                2
# 0                3
# 1                4
# 5                5
# 2                6
# 6                7
# 7                8
# 8                9

# %%
# y_pred = grid_search.predict(X_test)
# print(y_pred[0:10])

## Winter barley (1510) = Winter cereal
## Winter cereal (1910) = Winter cereal
## Winter wheat (1110) = Winter cereal

y_pred[y_pred=="Winter barley"] = "Winter cereal"
y_pred[y_pred=="Winter wheat"] = "Winter cereal"
y_test[y_test=="Winter barley"] = "Winter cereal"
y_test[y_test=="Winter wheat"] = "Winter cereal"

# %%
print("Accuracy on test set: "+str(accuracy_score(y_test,y_pred))[0:5])
prec, rec, fscore, sup = precision_recall_fscore_support(y_test,y_pred)
# plot_confusion_matrix(grid_search,X_test, y_test)
# plt.show()
# Out:
# Accuracy on test set: 0.816
